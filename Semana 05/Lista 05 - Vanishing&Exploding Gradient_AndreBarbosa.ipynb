# %% [markdown]
# <img src="https://github.com/alan-barzilay/NLPortugues/blob/master/imagens/logo_nlportugues.png?raw=true"  style="height:65%" align="right">
#
#
# # Lista 5 - Vanishing & Exploding Gradient
# **Nome:** André Barbosa
#
# **Numero Usp:** 7971751
#
#
#
#
#
#
#
#
#
# ______________

# %% [markdown]
# Nessa lista exploraremos alguns problemas que podemos encontrar ao treinarmos uma rede recorrente. Esses problemas não são únicos das redes recorrentes, qualquer rede profunda pode sofrer de vanishing e exploding gradient mas as redes recorrentes são especialmente instaveis devido a utilização da mesma matriz de pesos repetidas vezes.
#
# Começaremos explorando o exploding gradient e alguns de seus sintomas, em seguida utilizaremos gradient cliping para combate-lo.
# Por fim estudaremos uma rede que sofre de vanishing gradient e utilizaremos o [TensorBoard](??) para visualizar os gradientes e pesos da rede para entender melhor sua dinâmica. Exploraremos tambem algumas maneiras de combater o vanishing gradient e como elas alteram a dinâmica da rede através do TensorBoard.
#
#
#
# Para essa aula é necessario instalar o TensorBoard

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# %load_ext tensorboard

from sklearn.datasets import make_circles
from numpy import where
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.initializers import RandomUniform





from utils import ExtendedTensorBoard

# %% [markdown]
# # Exploding
#
# Para essa parte da lista nós preparamos uma rede, note como a *loss* cresce exponencialmente até virar infinita e logo em seguida NaN. Esse é um sintoma classico de exploding gradient. O gradiente está tão elevado que a cada etapa de backpropagation o passo de atualização dos parametros leva a um aumento na *loss* e isso segue crescendo até que exploda.

# %%
def f1(x):
    return 5+ 10*x

xs = [x for x in range(100)]
ys = [f1(x) for x in range(100)]

# %%
opt = keras.optimizers.SGD()
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer=opt, loss="mean_squared_error")
model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 526132252246016.0000
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 126593932795163303094274490368.0000
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: inf
# Epoch 4/400
# 4/4 [==============================] - 0s 1ms/step - loss: inf
# Epoch 5/400
# 4/4 [==============================] - 0s 1ms/step - loss: inf
# Epoch 6/400
# 4/4 [==============================] - 0s 980us/step - loss: nan
# Epoch 7/400
# 4/4 [==============================] - 0s 884us/step - loss: nan
# Epoch 8/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 9/400
# 4/4 [==============================] - 0s 941us/step - loss: nan
# Epoch 10/400
# 4/4 [==============================] - 0s 964us/step - loss: nan
# Epoch 11/400
# 4/4 [==============================] - 0s 871us/step - loss: nan
# Epoch 12/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 13/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 14/400
# 4/4 [==============================] - 0s 876us/step - loss: nan
# Epoch 15/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 16/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 17/400
# 4/4 [==============================] - 0s 901us/step - loss: nan
# Epoch 18/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 19/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 20/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 21/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 22/400
# 4/4 [==============================] - 0s 863us/step - loss: nan
# Epoch 23/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 24/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 25/400
# 4/4 [==============================] - 0s 871us/step - loss: nan
# Epoch 26/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 27/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 28/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 29/400
# 4/4 [==============================] - 0s 899us/step - loss: nan
# Epoch 30/400
# 4/4 [==============================] - 0s 944us/step - loss: nan
# Epoch 31/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 32/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 33/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 34/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 35/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 36/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 37/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 38/400
# 4/4 [==============================] - 0s 877us/step - loss: nan
# Epoch 39/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 40/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 41/400
# 4/4 [==============================] - 0s 932us/step - loss: nan
# Epoch 42/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 43/400
# 4/4 [==============================] - 0s 936us/step - loss: nan
# Epoch 44/400
# 4/4 [==============================] - 0s 869us/step - loss: nan
# Epoch 45/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 46/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 47/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 48/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 49/400
# 4/4 [==============================] - 0s 957us/step - loss: nan
# Epoch 50/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 51/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 52/400
# 4/4 [==============================] - 0s 841us/step - loss: nan
# Epoch 53/400
# 4/4 [==============================] - 0s 862us/step - loss: nan
# Epoch 54/400
# 4/4 [==============================] - 0s 904us/step - loss: nan
# Epoch 55/400
# 4/4 [==============================] - 0s 865us/step - loss: nan
# Epoch 56/400
# 4/4 [==============================] - 0s 845us/step - loss: nan
# Epoch 57/400
# 4/4 [==============================] - 0s 897us/step - loss: nan
# Epoch 58/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 59/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 60/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 61/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 62/400
# 4/4 [==============================] - 0s 928us/step - loss: nan
# Epoch 63/400
# 4/4 [==============================] - 0s 908us/step - loss: nan
# Epoch 64/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 65/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 66/400
# 4/4 [==============================] - 0s 923us/step - loss: nan
# Epoch 67/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 68/400
# 4/4 [==============================] - 0s 913us/step - loss: nan
# Epoch 69/400
# 4/4 [==============================] - 0s 862us/step - loss: nan
# Epoch 70/400
# 4/4 [==============================] - 0s 852us/step - loss: nan
# Epoch 71/400
# 4/4 [==============================] - 0s 997us/step - loss: nan
# Epoch 72/400
# 4/4 [==============================] - 0s 973us/step - loss: nan
# Epoch 73/400
# 4/4 [==============================] - 0s 916us/step - loss: nan
# Epoch 74/400
# 4/4 [==============================] - 0s 987us/step - loss: nan
# Epoch 75/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 76/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 77/400
# 4/4 [==============================] - 0s 884us/step - loss: nan
# Epoch 78/400
# 4/4 [==============================] - 0s 911us/step - loss: nan
# Epoch 79/400
# 4/4 [==============================] - 0s 982us/step - loss: nan
# Epoch 80/400
# 4/4 [==============================] - 0s 881us/step - loss: nan
# Epoch 81/400
# 4/4 [==============================] - 0s 895us/step - loss: nan
# Epoch 82/400
# 4/4 [==============================] - 0s 811us/step - loss: nan
# Epoch 83/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 84/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 85/400
# 4/4 [==============================] - 0s 852us/step - loss: nan
# Epoch 86/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 87/400
# 4/4 [==============================] - 0s 943us/step - loss: nan
# Epoch 88/400
# 4/4 [==============================] - 0s 955us/step - loss: nan
# Epoch 89/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 90/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 91/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 92/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 93/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 94/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 95/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 96/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 97/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 98/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 99/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 100/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 101/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 102/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 103/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 104/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 105/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 106/400
# 4/4 [==============================] - 0s 830us/step - loss: nan
# Epoch 107/400
# 4/4 [==============================] - 0s 913us/step - loss: nan
# Epoch 108/400
# 4/4 [==============================] - 0s 862us/step - loss: nan
# Epoch 109/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 110/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 111/400
# 4/4 [==============================] - 0s 958us/step - loss: nan
# Epoch 112/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 113/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 114/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 115/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 116/400
# 4/4 [==============================] - 0s 824us/step - loss: nan
# Epoch 117/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 118/400
# 4/4 [==============================] - 0s 926us/step - loss: nan
# Epoch 119/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 120/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 121/400
# 4/4 [==============================] - 0s 829us/step - loss: nan
# Epoch 122/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 123/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 124/400
# 4/4 [==============================] - 0s 940us/step - loss: nan
# Epoch 125/400
# 4/4 [==============================] - 0s 924us/step - loss: nan
# Epoch 126/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 127/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 128/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 129/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 130/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 131/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 132/400
# 4/4 [==============================] - 0s 872us/step - loss: nan
# Epoch 133/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 134/400
# 4/4 [==============================] - 0s 847us/step - loss: nan
# Epoch 135/400
# 4/4 [==============================] - 0s 840us/step - loss: nan
# Epoch 136/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 137/400
# 4/4 [==============================] - 0s 991us/step - loss: nan
# Epoch 138/400
# 4/4 [==============================] - 0s 879us/step - loss: nan
# Epoch 139/400
# 4/4 [==============================] - 0s 840us/step - loss: nan
# Epoch 140/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 141/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 142/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 143/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 144/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 145/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 146/400
# 4/4 [==============================] - 0s 853us/step - loss: nan
# Epoch 147/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 148/400
# 4/4 [==============================] - 0s 926us/step - loss: nan
# Epoch 149/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 150/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 151/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 152/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 153/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 154/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 155/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 156/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 157/400
# 4/4 [==============================] - 0s 971us/step - loss: nan
# Epoch 158/400
# 4/4 [==============================] - 0s 986us/step - loss: nan
# Epoch 159/400
# 4/4 [==============================] - 0s 977us/step - loss: nan
# Epoch 160/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 161/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 162/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 163/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 164/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 165/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 166/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 167/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 168/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 169/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 170/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 171/400
# 4/4 [==============================] - 0s 942us/step - loss: nan
# Epoch 172/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 173/400
# 4/4 [==============================] - 0s 909us/step - loss: nan
# Epoch 174/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 175/400
# 4/4 [==============================] - 0s 889us/step - loss: nan
# Epoch 176/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 177/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 178/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 179/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 180/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 181/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 182/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 183/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 184/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 185/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 186/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 187/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 188/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 189/400
# 4/4 [==============================] - 0s 8ms/step - loss: nan
# Epoch 190/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 191/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 192/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 193/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 194/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 195/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 196/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 197/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 198/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 199/400
# 4/4 [==============================] - 0s 5ms/step - loss: nan
# Epoch 200/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 201/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 202/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 203/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 204/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 205/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 206/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 207/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 208/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 209/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 210/400
# 4/4 [==============================] - 0s 941us/step - loss: nan
# Epoch 211/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 212/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 213/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 214/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 215/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 216/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 217/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 218/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 219/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 220/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 221/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 222/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 223/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 224/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 225/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 226/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 227/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 228/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 229/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 230/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 231/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 232/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 233/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 234/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 235/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 236/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 237/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 238/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 239/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 240/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 241/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 242/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 243/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 244/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 245/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 246/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 247/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 248/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 249/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 250/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 251/400
# 4/4 [==============================] - 0s 932us/step - loss: nan
# Epoch 252/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 253/400
# 4/4 [==============================] - 0s 940us/step - loss: nan
# Epoch 254/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 255/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 256/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 257/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 258/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 259/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 260/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 261/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 262/400
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 263/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 264/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 265/400
# 4/4 [==============================] - 0s 957us/step - loss: nan
# Epoch 266/400
# 4/4 [==============================] - 0s 995us/step - loss: nan
# Epoch 267/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 268/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 269/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 270/400
# 4/4 [==============================] - 0s 946us/step - loss: nan
# Epoch 271/400
# 4/4 [==============================] - 0s 898us/step - loss: nan
# Epoch 272/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 273/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 274/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 275/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 276/400
# 4/4 [==============================] - 0s 830us/step - loss: nan
# Epoch 277/400
# 4/4 [==============================] - 0s 912us/step - loss: nan
# Epoch 278/400
# 4/4 [==============================] - 0s 993us/step - loss: nan
# Epoch 279/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 280/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 281/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 282/400
# 4/4 [==============================] - 0s 908us/step - loss: nan
# Epoch 283/400
# 4/4 [==============================] - 0s 864us/step - loss: nan
# Epoch 284/400
# 4/4 [==============================] - 0s 914us/step - loss: nan
# Epoch 285/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 286/400
# 4/4 [==============================] - 0s 900us/step - loss: nan
# Epoch 287/400
# 4/4 [==============================] - 0s 980us/step - loss: nan
# Epoch 288/400
# 4/4 [==============================] - 0s 985us/step - loss: nan
# Epoch 289/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 290/400
# 4/4 [==============================] - 0s 906us/step - loss: nan
# Epoch 291/400
# 4/4 [==============================] - 0s 838us/step - loss: nan
# Epoch 292/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 293/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 294/400
# 4/4 [==============================] - 0s 879us/step - loss: nan
# Epoch 295/400
# 4/4 [==============================] - 0s 941us/step - loss: nan
# Epoch 296/400
# 4/4 [==============================] - 0s 986us/step - loss: nan
# Epoch 297/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 298/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 299/400
# 4/4 [==============================] - 0s 897us/step - loss: nan
# Epoch 300/400
# 4/4 [==============================] - 0s 991us/step - loss: nan
# Epoch 301/400
# 4/4 [==============================] - 0s 850us/step - loss: nan
# Epoch 302/400
# 4/4 [==============================] - 0s 864us/step - loss: nan
# Epoch 303/400
# 4/4 [==============================] - 0s 992us/step - loss: nan
# Epoch 304/400
# 4/4 [==============================] - 0s 938us/step - loss: nan
# Epoch 305/400
# 4/4 [==============================] - 0s 895us/step - loss: nan
# Epoch 306/400
# 4/4 [==============================] - 0s 885us/step - loss: nan
# Epoch 307/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 308/400
# 4/4 [==============================] - 0s 876us/step - loss: nan
# Epoch 309/400
# 4/4 [==============================] - 0s 854us/step - loss: nan
# Epoch 310/400
# 4/4 [==============================] - 0s 934us/step - loss: nan
# Epoch 311/400
# 4/4 [==============================] - 0s 853us/step - loss: nan
# Epoch 312/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 313/400
# 4/4 [==============================] - 0s 859us/step - loss: nan
# Epoch 314/400
# 4/4 [==============================] - 0s 969us/step - loss: nan
# Epoch 315/400
# 4/4 [==============================] - 0s 900us/step - loss: nan
# Epoch 316/400
# 4/4 [==============================] - 0s 934us/step - loss: nan
# Epoch 317/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 318/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 319/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 320/400
# 4/4 [==============================] - 0s 907us/step - loss: nan
# Epoch 321/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 322/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 323/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 324/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 325/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 326/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 327/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 328/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 329/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 330/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 331/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 332/400
# 4/4 [==============================] - 0s 897us/step - loss: nan
# Epoch 333/400
# 4/4 [==============================] - 0s 966us/step - loss: nan
# Epoch 334/400
# 4/4 [==============================] - 0s 848us/step - loss: nan
# Epoch 335/400
# 4/4 [==============================] - 0s 832us/step - loss: nan
# Epoch 336/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 337/400
# 4/4 [==============================] - 0s 952us/step - loss: nan
# Epoch 338/400
# 4/4 [==============================] - 0s 994us/step - loss: nan
# Epoch 339/400
# 4/4 [==============================] - 0s 1000us/step - loss: nan
# Epoch 340/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 341/400
# 4/4 [==============================] - 0s 963us/step - loss: nan
# Epoch 342/400
# 4/4 [==============================] - 0s 952us/step - loss: nan
# Epoch 343/400
# 4/4 [==============================] - 0s 895us/step - loss: nan
# Epoch 344/400
# 4/4 [==============================] - 0s 974us/step - loss: nan
# Epoch 345/400
# 4/4 [==============================] - 0s 881us/step - loss: nan
# Epoch 346/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 347/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 348/400
# 4/4 [==============================] - 0s 885us/step - loss: nan
# Epoch 349/400
# 4/4 [==============================] - 0s 964us/step - loss: nan
# Epoch 350/400
# 4/4 [==============================] - 0s 885us/step - loss: nan
# Epoch 351/400
# 4/4 [==============================] - 0s 911us/step - loss: nan
# Epoch 352/400
# 4/4 [==============================] - 0s 861us/step - loss: nan
# Epoch 353/400
# 4/4 [==============================] - 0s 961us/step - loss: nan
# Epoch 354/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 355/400
# 4/4 [==============================] - 0s 966us/step - loss: nan
# Epoch 356/400
# 4/4 [==============================] - 0s 893us/step - loss: nan
# Epoch 357/400
# 4/4 [==============================] - 0s 957us/step - loss: nan
# Epoch 358/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 359/400
# 4/4 [==============================] - 0s 879us/step - loss: nan
# Epoch 360/400
# 4/4 [==============================] - 0s 959us/step - loss: nan
# Epoch 361/400
# 4/4 [==============================] - 0s 953us/step - loss: nan
# Epoch 362/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 363/400
# 4/4 [==============================] - 0s 952us/step - loss: nan
# Epoch 364/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 365/400
# 4/4 [==============================] - 0s 898us/step - loss: nan
# Epoch 366/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 367/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 368/400
# 4/4 [==============================] - 0s 882us/step - loss: nan
# Epoch 369/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 370/400
# 4/4 [==============================] - 0s 950us/step - loss: nan
# Epoch 371/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 372/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 373/400
# 4/4 [==============================] - 0s 889us/step - loss: nan
# Epoch 374/400
# 4/4 [==============================] - 0s 854us/step - loss: nan
# Epoch 375/400
# 4/4 [==============================] - 0s 970us/step - loss: nan
# Epoch 376/400
# 4/4 [==============================] - 0s 879us/step - loss: nan
# Epoch 377/400
# 4/4 [==============================] - 0s 935us/step - loss: nan
# Epoch 378/400
# 4/4 [==============================] - 0s 948us/step - loss: nan
# Epoch 379/400
# 4/4 [==============================] - 0s 944us/step - loss: nan
# Epoch 380/400
# 4/4 [==============================] - 0s 953us/step - loss: nan
# Epoch 381/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 382/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 383/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 384/400
# 4/4 [==============================] - 0s 950us/step - loss: nan
# Epoch 385/400
# 4/4 [==============================] - 0s 946us/step - loss: nan
# Epoch 386/400
# 4/4 [==============================] - 0s 953us/step - loss: nan
# Epoch 387/400
# 4/4 [==============================] - 0s 837us/step - loss: nan
# Epoch 388/400
# 4/4 [==============================] - 0s 848us/step - loss: nan
# Epoch 389/400
# 4/4 [==============================] - 0s 844us/step - loss: nan
# Epoch 390/400
# 4/4 [==============================] - 0s 869us/step - loss: nan
# Epoch 391/400
# 4/4 [==============================] - 0s 976us/step - loss: nan
# Epoch 392/400
# 4/4 [==============================] - 0s 998us/step - loss: nan
# Epoch 393/400
# 4/4 [==============================] - 0s 963us/step - loss: nan
# Epoch 394/400
# 4/4 [==============================] - 0s 990us/step - loss: nan
# Epoch 395/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 396/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 397/400
# 4/4 [==============================] - 0s 3ms/step - loss: nan
# Epoch 398/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 399/400
# 4/4 [==============================] - 0s 2ms/step - loss: nan
# Epoch 400/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan

# %% [markdown]
# ## Gradient Cliping
# ## <font color='blue'>Questão 1 </font>
#
#
# Utilizando a mesma arquitetura, realize gradient clipping no otimizador para contornar o problema de exploding gradient, compile e treine seu novo modelo.
# Você pode usar tanto o parametro `clipvalue` quanto `clipnorm` desde que sua rede consiga minimizar a loss.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# Seu código aqui
opt = keras.optimizers.SGD(clipnorm=1.0)
model.compile(optimizer=opt, loss="mean_squared_error")


model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 1ms/step - loss: 445657.9688
# Epoch 2/400
# 4/4 [==============================] - 0s 970us/step - loss: 442630.4375
# Epoch 3/400
# 4/4 [==============================] - 0s 930us/step - loss: 439378.9688
# Epoch 4/400
# 4/4 [==============================] - 0s 940us/step - loss: 436395.8125
# Epoch 5/400
# 4/4 [==============================] - 0s 903us/step - loss: 433354.3750
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: 430263.0312
# Epoch 7/400
# 4/4 [==============================] - 0s 1ms/step - loss: 427175.5938
# Epoch 8/400
# 4/4 [==============================] - 0s 924us/step - loss: 424189.0312
# Epoch 9/400
# 4/4 [==============================] - 0s 1ms/step - loss: 421145.2812
# Epoch 10/400
# 4/4 [==============================] - 0s 981us/step - loss: 418124.7500
# Epoch 11/400
# 4/4 [==============================] - 0s 1ms/step - loss: 415141.6875
# Epoch 12/400
# 4/4 [==============================] - 0s 857us/step - loss: 412131.0000
# Epoch 13/400
# 4/4 [==============================] - 0s 1ms/step - loss: 409038.9688
# Epoch 14/400
# 4/4 [==============================] - 0s 1ms/step - loss: 406231.2500
# Epoch 15/400
# 4/4 [==============================] - 0s 1ms/step - loss: 403197.3125
# Epoch 16/400
# 4/4 [==============================] - 0s 2ms/step - loss: 400306.2812
# Epoch 17/400
# 4/4 [==============================] - 0s 1ms/step - loss: 397326.7188
# Epoch 18/400
# 4/4 [==============================] - 0s 1ms/step - loss: 394500.5938
# Epoch 19/400
# 4/4 [==============================] - 0s 1ms/step - loss: 391481.6250
# Epoch 20/400
# 4/4 [==============================] - 0s 1ms/step - loss: 388512.1250
# Epoch 21/400
# 4/4 [==============================] - 0s 1ms/step - loss: 385718.0938
# Epoch 22/400
# 4/4 [==============================] - 0s 1ms/step - loss: 382760.0312
# Epoch 23/400
# 4/4 [==============================] - 0s 859us/step - loss: 379979.1250
# Epoch 24/400
# 4/4 [==============================] - 0s 1ms/step - loss: 377041.4062
# Epoch 25/400
# 4/4 [==============================] - 0s 1ms/step - loss: 374245.7500
# Epoch 26/400
# 4/4 [==============================] - 0s 966us/step - loss: 371346.0000
# Epoch 27/400
# 4/4 [==============================] - 0s 870us/step - loss: 368510.6250
# Epoch 28/400
# 4/4 [==============================] - 0s 1ms/step - loss: 365766.3750
# Epoch 29/400
# 4/4 [==============================] - 0s 2ms/step - loss: 362944.3125
# Epoch 30/400
# 4/4 [==============================] - 0s 1ms/step - loss: 360116.3125
# Epoch 31/400
# 4/4 [==============================] - 0s 998us/step - loss: 357358.7500
# Epoch 32/400
# 4/4 [==============================] - 0s 933us/step - loss: 354642.4062
# Epoch 33/400
# 4/4 [==============================] - 0s 1ms/step - loss: 351804.7188
# Epoch 34/400
# 4/4 [==============================] - 0s 848us/step - loss: 348958.8125
# Epoch 35/400
# 4/4 [==============================] - 0s 929us/step - loss: 346337.8438
# Epoch 36/400
# 4/4 [==============================] - 0s 893us/step - loss: 343595.0000
# Epoch 37/400
# 4/4 [==============================] - 0s 879us/step - loss: 340912.1875
# Epoch 38/400
# 4/4 [==============================] - 0s 884us/step - loss: 338072.7500
# Epoch 39/400
# 4/4 [==============================] - 0s 948us/step - loss: 335345.3750
# Epoch 40/400
# 4/4 [==============================] - 0s 934us/step - loss: 332842.9375
# Epoch 41/400
# 4/4 [==============================] - 0s 1ms/step - loss: 330070.7812
# Epoch 42/400
# 4/4 [==============================] - 0s 879us/step - loss: 327336.8750
# Epoch 43/400
# 4/4 [==============================] - 0s 972us/step - loss: 324716.3750
# Epoch 44/400
# 4/4 [==============================] - 0s 880us/step - loss: 322055.7500
# Epoch 45/400
# 4/4 [==============================] - 0s 913us/step - loss: 319442.4688
# Epoch 46/400
# 4/4 [==============================] - 0s 888us/step - loss: 316848.8438
# Epoch 47/400
# 4/4 [==============================] - 0s 929us/step - loss: 314120.9375
# Epoch 48/400
# 4/4 [==============================] - 0s 881us/step - loss: 311617.3125
# Epoch 49/400
# 4/4 [==============================] - 0s 1ms/step - loss: 308970.7812
# Epoch 50/400
# 4/4 [==============================] - 0s 833us/step - loss: 306473.4062
# Epoch 51/400
# 4/4 [==============================] - 0s 850us/step - loss: 303864.3750
# Epoch 52/400
# 4/4 [==============================] - 0s 902us/step - loss: 301370.5938
# Epoch 53/400
# 4/4 [==============================] - 0s 892us/step - loss: 298719.1875
# Epoch 54/400
# 4/4 [==============================] - 0s 876us/step - loss: 296189.8750
# Epoch 55/400
# 4/4 [==============================] - 0s 948us/step - loss: 293555.9062
# Epoch 56/400
# 4/4 [==============================] - 0s 893us/step - loss: 291244.4688
# Epoch 57/400
# 4/4 [==============================] - 0s 882us/step - loss: 288686.9688
# Epoch 58/400
# 4/4 [==============================] - 0s 1ms/step - loss: 286169.6250
# Epoch 59/400
# 4/4 [==============================] - 0s 821us/step - loss: 283669.0625
# Epoch 60/400
# 4/4 [==============================] - 0s 862us/step - loss: 281244.8438
# Epoch 61/400
# 4/4 [==============================] - 0s 880us/step - loss: 278804.0938
# Epoch 62/400
# 4/4 [==============================] - 0s 917us/step - loss: 276326.1562
# Epoch 63/400
# 4/4 [==============================] - 0s 913us/step - loss: 273924.8438
# Epoch 64/400
# 4/4 [==============================] - 0s 1ms/step - loss: 271431.7500
# Epoch 65/400
# 4/4 [==============================] - 0s 1ms/step - loss: 268998.7188
# Epoch 66/400
# 4/4 [==============================] - 0s 2ms/step - loss: 266627.1250
# Epoch 67/400
# 4/4 [==============================] - 0s 1ms/step - loss: 264200.0938
# Epoch 68/400
# 4/4 [==============================] - 0s 1ms/step - loss: 261818.4219
# Epoch 69/400
# 4/4 [==============================] - 0s 1ms/step - loss: 259417.3125
# Epoch 70/400
# 4/4 [==============================] - 0s 2ms/step - loss: 257154.0156
# Epoch 71/400
# 4/4 [==============================] - 0s 1ms/step - loss: 254743.7969
# Epoch 72/400
# 4/4 [==============================] - 0s 937us/step - loss: 252466.5469
# Epoch 73/400
# 4/4 [==============================] - 0s 3ms/step - loss: 250045.2031
# Epoch 74/400
# 4/4 [==============================] - 0s 2ms/step - loss: 247754.8750
# Epoch 75/400
# 4/4 [==============================] - 0s 2ms/step - loss: 245394.9062
# Epoch 76/400
# 4/4 [==============================] - 0s 1ms/step - loss: 243128.9062
# Epoch 77/400
# 4/4 [==============================] - 0s 1ms/step - loss: 240857.1875
# Epoch 78/400
# 4/4 [==============================] - 0s 891us/step - loss: 238552.3750
# Epoch 79/400
# 4/4 [==============================] - 0s 885us/step - loss: 236294.6875
# Epoch 80/400
# 4/4 [==============================] - 0s 921us/step - loss: 234064.8438
# Epoch 81/400
# 4/4 [==============================] - 0s 936us/step - loss: 231798.4531
# Epoch 82/400
# 4/4 [==============================] - 0s 890us/step - loss: 229473.7344
# Epoch 83/400
# 4/4 [==============================] - 0s 907us/step - loss: 227287.2812
# Epoch 84/400
# 4/4 [==============================] - 0s 959us/step - loss: 225083.7031
# Epoch 85/400
# 4/4 [==============================] - 0s 1ms/step - loss: 222887.2344
# Epoch 86/400
# 4/4 [==============================] - 0s 862us/step - loss: 220731.3125
# Epoch 87/400
# 4/4 [==============================] - 0s 859us/step - loss: 218604.7812
# Epoch 88/400
# 4/4 [==============================] - 0s 860us/step - loss: 216367.4844
# Epoch 89/400
# 4/4 [==============================] - 0s 911us/step - loss: 214215.1875
# Epoch 90/400
# 4/4 [==============================] - 0s 967us/step - loss: 212043.8125
# Epoch 91/400
# 4/4 [==============================] - 0s 902us/step - loss: 209913.3750
# Epoch 92/400
# 4/4 [==============================] - 0s 1ms/step - loss: 207771.5938
# Epoch 93/400
# 4/4 [==============================] - 0s 983us/step - loss: 205693.0000
# Epoch 94/400
# 4/4 [==============================] - 0s 1ms/step - loss: 203579.0781
# Epoch 95/400
# 4/4 [==============================] - 0s 3ms/step - loss: 201534.1562
# Epoch 96/400
# 4/4 [==============================] - 0s 2ms/step - loss: 199439.7812
# Epoch 97/400
# 4/4 [==============================] - 0s 2ms/step - loss: 197303.9844
# Epoch 98/400
# 4/4 [==============================] - 0s 888us/step - loss: 195199.2188
# Epoch 99/400
# 4/4 [==============================] - 0s 2ms/step - loss: 193235.9844
# Epoch 100/400
# 4/4 [==============================] - 0s 944us/step - loss: 191218.2812
# Epoch 101/400
# 4/4 [==============================] - 0s 874us/step - loss: 189163.5000
# Epoch 102/400
# 4/4 [==============================] - 0s 1ms/step - loss: 187173.4531
# Epoch 103/400
# 4/4 [==============================] - 0s 980us/step - loss: 185135.0469
# Epoch 104/400
# 4/4 [==============================] - 0s 914us/step - loss: 183136.3125
# Epoch 105/400
# 4/4 [==============================] - 0s 884us/step - loss: 181160.8750
# Epoch 106/400
# 4/4 [==============================] - 0s 883us/step - loss: 179208.0000
# Epoch 107/400
# 4/4 [==============================] - 0s 1ms/step - loss: 177225.9219
# Epoch 108/400
# 4/4 [==============================] - 0s 913us/step - loss: 175246.2656
# Epoch 109/400
# 4/4 [==============================] - 0s 898us/step - loss: 173347.8594
# Epoch 110/400
# 4/4 [==============================] - 0s 1ms/step - loss: 171311.2656
# Epoch 111/400
# 4/4 [==============================] - 0s 1ms/step - loss: 169480.3438
# Epoch 112/400
# 4/4 [==============================] - 0s 881us/step - loss: 167497.6875
# Epoch 113/400
# 4/4 [==============================] - 0s 896us/step - loss: 165664.3750
# Epoch 114/400
# 4/4 [==============================] - 0s 870us/step - loss: 163638.8750
# Epoch 115/400
# 4/4 [==============================] - 0s 855us/step - loss: 161887.5469
# Epoch 116/400
# 4/4 [==============================] - 0s 1ms/step - loss: 160055.5312
# Epoch 117/400
# 4/4 [==============================] - 0s 866us/step - loss: 158195.6562
# Epoch 118/400
# 4/4 [==============================] - 0s 1ms/step - loss: 156335.5781
# Epoch 119/400
# 4/4 [==============================] - 0s 881us/step - loss: 154497.7031
# Epoch 120/400
# 4/4 [==============================] - 0s 2ms/step - loss: 152572.1250
# Epoch 121/400
# 4/4 [==============================] - 0s 1ms/step - loss: 150838.8125
# Epoch 122/400
# 4/4 [==============================] - 0s 896us/step - loss: 149099.1250
# Epoch 123/400
# 4/4 [==============================] - 0s 998us/step - loss: 147282.2969
# Epoch 124/400
# 4/4 [==============================] - 0s 973us/step - loss: 145472.1875
# Epoch 125/400
# 4/4 [==============================] - 0s 905us/step - loss: 143744.9688
# Epoch 126/400
# 4/4 [==============================] - 0s 866us/step - loss: 141898.2500
# Epoch 127/400
# 4/4 [==============================] - 0s 866us/step - loss: 140199.7031
# Epoch 128/400
# 4/4 [==============================] - 0s 1ms/step - loss: 138431.7500
# Epoch 129/400
# 4/4 [==============================] - 0s 889us/step - loss: 136731.7969
# Epoch 130/400
# 4/4 [==============================] - 0s 987us/step - loss: 135039.5000
# Epoch 131/400
# 4/4 [==============================] - 0s 1ms/step - loss: 133326.4062
# Epoch 132/400
# 4/4 [==============================] - 0s 1ms/step - loss: 131572.1406
# Epoch 133/400
# 4/4 [==============================] - 0s 1ms/step - loss: 129912.3672
# Epoch 134/400
# 4/4 [==============================] - 0s 924us/step - loss: 128192.6016
# Epoch 135/400
# 4/4 [==============================] - 0s 891us/step - loss: 126596.7969
# Epoch 136/400
# 4/4 [==============================] - 0s 870us/step - loss: 125001.2109
# Epoch 137/400
# 4/4 [==============================] - 0s 888us/step - loss: 123277.6797
# Epoch 138/400
# 4/4 [==============================] - 0s 867us/step - loss: 121678.0625
# Epoch 139/400
# 4/4 [==============================] - 0s 1ms/step - loss: 120076.8125
# Epoch 140/400
# 4/4 [==============================] - 0s 925us/step - loss: 118445.5938
# Epoch 141/400
# 4/4 [==============================] - 0s 851us/step - loss: 116888.1016
# Epoch 142/400
# 4/4 [==============================] - 0s 871us/step - loss: 115287.7734
# Epoch 143/400
# 4/4 [==============================] - 0s 959us/step - loss: 113681.9297
# Epoch 144/400
# 4/4 [==============================] - 0s 855us/step - loss: 112137.8125
# Epoch 145/400
# 4/4 [==============================] - 0s 913us/step - loss: 110567.0078
# Epoch 146/400
# 4/4 [==============================] - 0s 2ms/step - loss: 109027.8203
# Epoch 147/400
# 4/4 [==============================] - 0s 3ms/step - loss: 107493.3438
# Epoch 148/400
# 4/4 [==============================] - 0s 3ms/step - loss: 106011.5234
# Epoch 149/400
# 4/4 [==============================] - 0s 2ms/step - loss: 104453.4375
# Epoch 150/400
# 4/4 [==============================] - 0s 3ms/step - loss: 103013.8672
# Epoch 151/400
# 4/4 [==============================] - 0s 1ms/step - loss: 101491.9922
# Epoch 152/400
# 4/4 [==============================] - 0s 1ms/step - loss: 100065.3672
# Epoch 153/400
# 4/4 [==============================] - 0s 972us/step - loss: 98561.2812
# Epoch 154/400
# 4/4 [==============================] - 0s 1ms/step - loss: 97088.4375
# Epoch 155/400
# 4/4 [==============================] - 0s 869us/step - loss: 95624.2578
# Epoch 156/400
# 4/4 [==============================] - 0s 1ms/step - loss: 94222.2266
# Epoch 157/400
# 4/4 [==============================] - 0s 1ms/step - loss: 92830.0703
# Epoch 158/400
# 4/4 [==============================] - 0s 831us/step - loss: 91378.1094
# Epoch 159/400
# 4/4 [==============================] - 0s 849us/step - loss: 89998.4219
# Epoch 160/400
# 4/4 [==============================] - 0s 954us/step - loss: 88588.4922
# Epoch 161/400
# 4/4 [==============================] - 0s 848us/step - loss: 87195.0000
# Epoch 162/400
# 4/4 [==============================] - 0s 941us/step - loss: 85869.7891
# Epoch 163/400
# 4/4 [==============================] - 0s 958us/step - loss: 84438.2422
# Epoch 164/400
# 4/4 [==============================] - 0s 905us/step - loss: 83161.3828
# Epoch 165/400
# 4/4 [==============================] - 0s 889us/step - loss: 81787.6328
# Epoch 166/400
# 4/4 [==============================] - 0s 920us/step - loss: 80433.8438
# Epoch 167/400
# 4/4 [==============================] - 0s 856us/step - loss: 79165.1406
# Epoch 168/400
# 4/4 [==============================] - 0s 1ms/step - loss: 77869.5625
# Epoch 169/400
# 4/4 [==============================] - 0s 1ms/step - loss: 76587.2188
# Epoch 170/400
# 4/4 [==============================] - 0s 2ms/step - loss: 75288.3125
# Epoch 171/400
# 4/4 [==============================] - 0s 1ms/step - loss: 73988.0859
# Epoch 172/400
# 4/4 [==============================] - 0s 3ms/step - loss: 72700.9062
# Epoch 173/400
# 4/4 [==============================] - 0s 1ms/step - loss: 71486.0078
# Epoch 174/400
# 4/4 [==============================] - 0s 3ms/step - loss: 70206.3984
# Epoch 175/400
# 4/4 [==============================] - 0s 1ms/step - loss: 69053.6172
# Epoch 176/400
# 4/4 [==============================] - 0s 952us/step - loss: 67862.7734
# Epoch 177/400
# 4/4 [==============================] - 0s 2ms/step - loss: 66559.5312
# Epoch 178/400
# 4/4 [==============================] - 0s 887us/step - loss: 65417.4258
# Epoch 179/400
# 4/4 [==============================] - 0s 964us/step - loss: 64218.5391
# Epoch 180/400
# 4/4 [==============================] - 0s 956us/step - loss: 63044.3984
# Epoch 181/400
# 4/4 [==============================] - 0s 977us/step - loss: 61870.6641
# Epoch 182/400
# 4/4 [==============================] - 0s 863us/step - loss: 60746.2109
# Epoch 183/400
# 4/4 [==============================] - 0s 898us/step - loss: 59554.7656
# Epoch 184/400
# 4/4 [==============================] - 0s 911us/step - loss: 58460.1016
# Epoch 185/400
# 4/4 [==============================] - 0s 906us/step - loss: 57334.1445
# Epoch 186/400
# 4/4 [==============================] - 0s 919us/step - loss: 56257.8906
# Epoch 187/400
# 4/4 [==============================] - 0s 909us/step - loss: 55159.1992
# Epoch 188/400
# 4/4 [==============================] - 0s 849us/step - loss: 54069.4766
# Epoch 189/400
# 4/4 [==============================] - 0s 925us/step - loss: 53013.6602
# Epoch 190/400
# 4/4 [==============================] - 0s 950us/step - loss: 51880.1562
# Epoch 191/400
# 4/4 [==============================] - 0s 954us/step - loss: 50865.8438
# Epoch 192/400
# 4/4 [==============================] - 0s 2ms/step - loss: 49813.4297
# Epoch 193/400
# 4/4 [==============================] - 0s 984us/step - loss: 48803.1094
# Epoch 194/400
# 4/4 [==============================] - 0s 929us/step - loss: 47742.3750
# Epoch 195/400
# 4/4 [==============================] - 0s 953us/step - loss: 46746.5703
# Epoch 196/400
# 4/4 [==============================] - 0s 952us/step - loss: 45755.3438
# Epoch 197/400
# 4/4 [==============================] - 0s 966us/step - loss: 44786.0234
# Epoch 198/400
# 4/4 [==============================] - 0s 859us/step - loss: 43779.5352
# Epoch 199/400
# 4/4 [==============================] - 0s 1ms/step - loss: 42835.4219
# Epoch 200/400
# 4/4 [==============================] - 0s 875us/step - loss: 41854.2539
# Epoch 201/400
# 4/4 [==============================] - 0s 889us/step - loss: 40908.1836
# Epoch 202/400
# 4/4 [==============================] - 0s 931us/step - loss: 39998.0078
# Epoch 203/400
# 4/4 [==============================] - 0s 1ms/step - loss: 39070.4844
# Epoch 204/400
# 4/4 [==============================] - 0s 883us/step - loss: 38155.5234
# Epoch 205/400
# 4/4 [==============================] - 0s 1ms/step - loss: 37235.1211
# Epoch 206/400
# 4/4 [==============================] - 0s 3ms/step - loss: 36314.2109
# Epoch 207/400
# 4/4 [==============================] - 0s 2ms/step - loss: 35444.4648
# Epoch 208/400
# 4/4 [==============================] - 0s 3ms/step - loss: 34581.8320
# Epoch 209/400
# 4/4 [==============================] - 0s 1ms/step - loss: 33716.7656
# Epoch 210/400
# 4/4 [==============================] - 0s 925us/step - loss: 32877.2383
# Epoch 211/400
# 4/4 [==============================] - 0s 1ms/step - loss: 32052.8359
# Epoch 212/400
# 4/4 [==============================] - 0s 1ms/step - loss: 31174.8574
# Epoch 213/400
# 4/4 [==============================] - 0s 2ms/step - loss: 30388.2148
# Epoch 214/400
# 4/4 [==============================] - 0s 1ms/step - loss: 29569.0957
# Epoch 215/400
# 4/4 [==============================] - 0s 849us/step - loss: 28791.4922
# Epoch 216/400
# 4/4 [==============================] - 0s 842us/step - loss: 27993.7656
# Epoch 217/400
# 4/4 [==============================] - 0s 864us/step - loss: 27231.8477
# Epoch 218/400
# 4/4 [==============================] - 0s 872us/step - loss: 26460.5391
# Epoch 219/400
# 4/4 [==============================] - 0s 969us/step - loss: 25727.4668
# Epoch 220/400
# 4/4 [==============================] - 0s 856us/step - loss: 24999.7773
# Epoch 221/400
# 4/4 [==============================] - 0s 863us/step - loss: 24267.4355
# Epoch 222/400
# 4/4 [==============================] - 0s 868us/step - loss: 23528.4473
# Epoch 223/400
# 4/4 [==============================] - 0s 891us/step - loss: 22816.0703
# Epoch 224/400
# 4/4 [==============================] - 0s 843us/step - loss: 22125.2480
# Epoch 225/400
# 4/4 [==============================] - 0s 837us/step - loss: 21437.4043
# Epoch 226/400
# 4/4 [==============================] - 0s 1ms/step - loss: 20740.3223
# Epoch 227/400
# 4/4 [==============================] - 0s 1ms/step - loss: 20079.5898
# Epoch 228/400
# 4/4 [==============================] - 0s 1ms/step - loss: 19444.6094
# Epoch 229/400
# 4/4 [==============================] - 0s 889us/step - loss: 18782.4453
# Epoch 230/400
# 4/4 [==============================] - 0s 930us/step - loss: 18184.8789
# Epoch 231/400
# 4/4 [==============================] - 0s 918us/step - loss: 17559.9961
# Epoch 232/400
# 4/4 [==============================] - 0s 938us/step - loss: 16927.5293
# Epoch 233/400
# 4/4 [==============================] - 0s 863us/step - loss: 16329.4111
# Epoch 234/400
# 4/4 [==============================] - 0s 1ms/step - loss: 15756.8887
# Epoch 235/400
# 4/4 [==============================] - 0s 2ms/step - loss: 15160.7930
# Epoch 236/400
# 4/4 [==============================] - 0s 1ms/step - loss: 14611.4639
# Epoch 237/400
# 4/4 [==============================] - 0s 906us/step - loss: 14064.9873
# Epoch 238/400
# 4/4 [==============================] - 0s 1ms/step - loss: 13507.2549
# Epoch 239/400
# 4/4 [==============================] - 0s 943us/step - loss: 12966.4346
# Epoch 240/400
# 4/4 [==============================] - 0s 1ms/step - loss: 12434.3076
# Epoch 241/400
# 4/4 [==============================] - 0s 865us/step - loss: 11925.7158
# Epoch 242/400
# 4/4 [==============================] - 0s 1ms/step - loss: 11434.4541
# Epoch 243/400
# 4/4 [==============================] - 0s 978us/step - loss: 10951.9326
# Epoch 244/400
# 4/4 [==============================] - 0s 1ms/step - loss: 10446.9766
# Epoch 245/400
# 4/4 [==============================] - 0s 1ms/step - loss: 9980.2422
# Epoch 246/400
# 4/4 [==============================] - 0s 3ms/step - loss: 9533.8672
# Epoch 247/400
# 4/4 [==============================] - 0s 2ms/step - loss: 9068.6494
# Epoch 248/400
# 4/4 [==============================] - 0s 3ms/step - loss: 8636.5029
# Epoch 249/400
# 4/4 [==============================] - 0s 947us/step - loss: 8223.8223
# Epoch 250/400
# 4/4 [==============================] - 0s 1ms/step - loss: 7776.1279
# Epoch 251/400
# 4/4 [==============================] - 0s 1ms/step - loss: 7382.4204
# Epoch 252/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6986.1914
# Epoch 253/400
# 4/4 [==============================] - 0s 2ms/step - loss: 6607.5093
# Epoch 254/400
# 4/4 [==============================] - 0s 2ms/step - loss: 6238.5171
# Epoch 255/400
# 4/4 [==============================] - 0s 915us/step - loss: 5868.8486
# Epoch 256/400
# 4/4 [==============================] - 0s 918us/step - loss: 5529.2300
# Epoch 257/400
# 4/4 [==============================] - 0s 915us/step - loss: 5198.9658
# Epoch 258/400
# 4/4 [==============================] - 0s 864us/step - loss: 4860.7515
# Epoch 259/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4543.9956
# Epoch 260/400
# 4/4 [==============================] - 0s 940us/step - loss: 4221.3589
# Epoch 261/400
# 4/4 [==============================] - 0s 927us/step - loss: 3935.9985
# Epoch 262/400
# 4/4 [==============================] - 0s 868us/step - loss: 3655.1997
# Epoch 263/400
# 4/4 [==============================] - 0s 884us/step - loss: 3373.0657
# Epoch 264/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3105.3931
# Epoch 265/400
# 4/4 [==============================] - 0s 879us/step - loss: 2850.3066
# Epoch 266/400
# 4/4 [==============================] - 0s 883us/step - loss: 2608.2224
# Epoch 267/400
# 4/4 [==============================] - 0s 906us/step - loss: 2375.7480
# Epoch 268/400
# 4/4 [==============================] - 0s 884us/step - loss: 2156.4907
# Epoch 269/400
# 4/4 [==============================] - 0s 867us/step - loss: 1946.9708
# Epoch 270/400
# 4/4 [==============================] - 0s 857us/step - loss: 1744.7382
# Epoch 271/400
# 4/4 [==============================] - 0s 958us/step - loss: 1561.4626
# Epoch 272/400
# 4/4 [==============================] - 0s 1ms/step - loss: 1387.1008
# Epoch 273/400
# 4/4 [==============================] - 0s 931us/step - loss: 1209.0911
# Epoch 274/400
# 4/4 [==============================] - 0s 902us/step - loss: 1057.3490
# Epoch 275/400
# 4/4 [==============================] - 0s 980us/step - loss: 917.6204
# Epoch 276/400
# 4/4 [==============================] - 0s 884us/step - loss: 782.5118
# Epoch 277/400
# 4/4 [==============================] - 0s 891us/step - loss: 653.6998
# Epoch 278/400
# 4/4 [==============================] - 0s 994us/step - loss: 542.7742
# Epoch 279/400
# 4/4 [==============================] - 0s 965us/step - loss: 438.2933
# Epoch 280/400
# 4/4 [==============================] - 0s 876us/step - loss: 350.9392
# Epoch 281/400
# 4/4 [==============================] - 0s 965us/step - loss: 270.3705
# Epoch 282/400
# 4/4 [==============================] - 0s 1ms/step - loss: 202.1930
# Epoch 283/400
# 4/4 [==============================] - 0s 1ms/step - loss: 143.7328
# Epoch 284/400
# 4/4 [==============================] - 0s 2ms/step - loss: 95.2060
# Epoch 285/400
# 4/4 [==============================] - 0s 2ms/step - loss: 56.6165
# Epoch 286/400
# 4/4 [==============================] - 0s 2ms/step - loss: 30.8239
# Epoch 287/400
# 4/4 [==============================] - 0s 3ms/step - loss: 16.2913
# Epoch 288/400
# 4/4 [==============================] - 0s 1ms/step - loss: 10.6531
# Epoch 289/400
# 4/4 [==============================] - 0s 916us/step - loss: 10.6357
# Epoch 290/400
# 4/4 [==============================] - 0s 1ms/step - loss: 10.4348
# Epoch 291/400
# 4/4 [==============================] - 0s 848us/step - loss: 9.9131
# Epoch 292/400
# 4/4 [==============================] - 0s 956us/step - loss: 10.0391
# Epoch 293/400
# 4/4 [==============================] - 0s 906us/step - loss: 9.8885
# Epoch 294/400
# 4/4 [==============================] - 0s 898us/step - loss: 9.8699
# Epoch 295/400
# 4/4 [==============================] - 0s 845us/step - loss: 10.0110
# Epoch 296/400
# 4/4 [==============================] - 0s 893us/step - loss: 9.4499
# Epoch 297/400
# 4/4 [==============================] - 0s 880us/step - loss: 9.3872
# Epoch 298/400
# 4/4 [==============================] - 0s 863us/step - loss: 9.3281
# Epoch 299/400
# 4/4 [==============================] - 0s 967us/step - loss: 9.1441
# Epoch 300/400
# 4/4 [==============================] - 0s 880us/step - loss: 9.1330
# Epoch 301/400
# 4/4 [==============================] - 0s 1ms/step - loss: 9.0286
# Epoch 302/400
# 4/4 [==============================] - 0s 860us/step - loss: 8.8681
# Epoch 303/400
# 4/4 [==============================] - 0s 920us/step - loss: 8.8599
# Epoch 304/400
# 4/4 [==============================] - 0s 1ms/step - loss: 8.8051
# Epoch 305/400
# 4/4 [==============================] - 0s 1ms/step - loss: 8.6099
# Epoch 306/400
# 4/4 [==============================] - 0s 885us/step - loss: 8.7867
# Epoch 307/400
# 4/4 [==============================] - 0s 841us/step - loss: 8.5244
# Epoch 308/400
# 4/4 [==============================] - 0s 945us/step - loss: 8.4004
# Epoch 309/400
# 4/4 [==============================] - 0s 961us/step - loss: 8.3246
# Epoch 310/400
# 4/4 [==============================] - 0s 1ms/step - loss: 8.1750
# Epoch 311/400
# 4/4 [==============================] - 0s 905us/step - loss: 8.4300
# Epoch 312/400
# 4/4 [==============================] - 0s 1ms/step - loss: 8.0714
# Epoch 313/400
# 4/4 [==============================] - 0s 884us/step - loss: 8.0543
# Epoch 314/400
# 4/4 [==============================] - 0s 879us/step - loss: 7.9410
# Epoch 315/400
# 4/4 [==============================] - 0s 924us/step - loss: 7.9395
# Epoch 316/400
# 4/4 [==============================] - 0s 984us/step - loss: 7.5803
# Epoch 317/400
# 4/4 [==============================] - 0s 947us/step - loss: 7.3504
# Epoch 318/400
# 4/4 [==============================] - 0s 924us/step - loss: 7.5457
# Epoch 319/400
# 4/4 [==============================] - 0s 930us/step - loss: 7.3261
# Epoch 320/400
# 4/4 [==============================] - 0s 901us/step - loss: 7.1576
# Epoch 321/400
# 4/4 [==============================] - 0s 883us/step - loss: 7.0701
# Epoch 322/400
# 4/4 [==============================] - 0s 904us/step - loss: 7.0516
# Epoch 323/400
# 4/4 [==============================] - 0s 949us/step - loss: 7.0656
# Epoch 324/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6.9320
# Epoch 325/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6.6661
# Epoch 326/400
# 4/4 [==============================] - 0s 908us/step - loss: 6.6072
# Epoch 327/400
# 4/4 [==============================] - 0s 916us/step - loss: 6.5322
# Epoch 328/400
# 4/4 [==============================] - 0s 987us/step - loss: 6.4485
# Epoch 329/400
# 4/4 [==============================] - 0s 927us/step - loss: 6.5124
# Epoch 330/400
# 4/4 [==============================] - 0s 963us/step - loss: 6.2974
# Epoch 331/400
# 4/4 [==============================] - 0s 1ms/step - loss: 6.2813
# Epoch 332/400
# 4/4 [==============================] - 0s 968us/step - loss: 6.2188
# Epoch 333/400
# 4/4 [==============================] - 0s 898us/step - loss: 5.7683
# Epoch 334/400
# 4/4 [==============================] - 0s 906us/step - loss: 5.8037
# Epoch 335/400
# 4/4 [==============================] - 0s 891us/step - loss: 5.5731
# Epoch 336/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.5529
# Epoch 337/400
# 4/4 [==============================] - 0s 2ms/step - loss: 5.5644
# Epoch 338/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5.4374
# Epoch 339/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5.2875
# Epoch 340/400
# 4/4 [==============================] - 0s 853us/step - loss: 5.5448
# Epoch 341/400
# 4/4 [==============================] - 0s 918us/step - loss: 5.2667
# Epoch 342/400
# 4/4 [==============================] - 0s 1ms/step - loss: 5.2408
# Epoch 343/400
# 4/4 [==============================] - 0s 923us/step - loss: 5.0018
# Epoch 344/400
# 4/4 [==============================] - 0s 961us/step - loss: 4.9402
# Epoch 345/400
# 4/4 [==============================] - 0s 857us/step - loss: 5.1516
# Epoch 346/400
# 4/4 [==============================] - 0s 910us/step - loss: 4.9195
# Epoch 347/400
# 4/4 [==============================] - 0s 904us/step - loss: 4.8146
# Epoch 348/400
# 4/4 [==============================] - 0s 933us/step - loss: 4.6266
# Epoch 349/400
# 4/4 [==============================] - 0s 940us/step - loss: 4.5073
# Epoch 350/400
# 4/4 [==============================] - 0s 962us/step - loss: 4.6267
# Epoch 351/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.4512
# Epoch 352/400
# 4/4 [==============================] - 0s 999us/step - loss: 4.2970
# Epoch 353/400
# 4/4 [==============================] - 0s 983us/step - loss: 4.3520
# Epoch 354/400
# 4/4 [==============================] - 0s 870us/step - loss: 4.5656
# Epoch 355/400
# 4/4 [==============================] - 0s 1ms/step - loss: 4.1172
# Epoch 356/400
# 4/4 [==============================] - 0s 878us/step - loss: 4.0190
# Epoch 357/400
# 4/4 [==============================] - 0s 919us/step - loss: 4.3065
# Epoch 358/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.9055
# Epoch 359/400
# 4/4 [==============================] - 0s 891us/step - loss: 4.0505
# Epoch 360/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.7514
# Epoch 361/400
# 4/4 [==============================] - 0s 876us/step - loss: 3.7679
# Epoch 362/400
# 4/4 [==============================] - 0s 994us/step - loss: 3.7389
# Epoch 363/400
# 4/4 [==============================] - 0s 935us/step - loss: 3.8076
# Epoch 364/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.7993
# Epoch 365/400
# 4/4 [==============================] - 0s 947us/step - loss: 3.5054
# Epoch 366/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.3941
# Epoch 367/400
# 4/4 [==============================] - 0s 928us/step - loss: 3.5172
# Epoch 368/400
# 4/4 [==============================] - 0s 998us/step - loss: 3.2098
# Epoch 369/400
# 4/4 [==============================] - 0s 955us/step - loss: 3.4098
# Epoch 370/400
# 4/4 [==============================] - 0s 957us/step - loss: 3.1746
# Epoch 371/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.2613
# Epoch 372/400
# 4/4 [==============================] - 0s 923us/step - loss: 3.0565
# Epoch 373/400
# 4/4 [==============================] - 0s 2ms/step - loss: 3.1486
# Epoch 374/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.2256
# Epoch 375/400
# 4/4 [==============================] - 0s 849us/step - loss: 3.3651
# Epoch 376/400
# 4/4 [==============================] - 0s 861us/step - loss: 2.8967
# Epoch 377/400
# 4/4 [==============================] - 0s 896us/step - loss: 2.7039
# Epoch 378/400
# 4/4 [==============================] - 0s 856us/step - loss: 2.8171
# Epoch 379/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.6988
# Epoch 380/400
# 4/4 [==============================] - 0s 920us/step - loss: 2.6867
# Epoch 381/400
# 4/4 [==============================] - 0s 938us/step - loss: 2.6032
# Epoch 382/400
# 4/4 [==============================] - 0s 993us/step - loss: 2.4687
# Epoch 383/400
# 4/4 [==============================] - 0s 935us/step - loss: 2.6013
# Epoch 384/400
# 4/4 [==============================] - 0s 1ms/step - loss: 3.0187
# Epoch 385/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.4343
# Epoch 386/400
# 4/4 [==============================] - 0s 838us/step - loss: 2.4112
# Epoch 387/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2778
# Epoch 388/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3927
# Epoch 389/400
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3237
# Epoch 390/400
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0792
# Epoch 391/400
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0461
# Epoch 392/400
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9679
# Epoch 393/400
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0999
# Epoch 394/400
# 4/4 [==============================] - 0s 976us/step - loss: 1.9529
# Epoch 395/400
# 4/4 [==============================] - 0s 965us/step - loss: 2.0125
# Epoch 396/400
# 4/4 [==============================] - 0s 859us/step - loss: 2.0342
# Epoch 397/400
# 4/4 [==============================] - 0s 983us/step - loss: 1.8606
# Epoch 398/400
# 4/4 [==============================] - 0s 862us/step - loss: 1.8114
# Epoch 399/400
# 4/4 [==============================] - 0s 893us/step - loss: 1.8631
# Epoch 400/400
# 4/4 [==============================] - 0s 877us/step - loss: 1.7470

# %% [markdown]
# ________________________
#
#
#
# # Vanishing
#
# Lidar com Vanishing Gradient é muito mais desafiador do que com exploding gradient. Não é trivial determinar se o baixo desempenho de sua rede é causado por vanishing gradient uma vez que seus sintomas são relativamente genericos e ele pode ser apenas mais um dos fatores que prejudicam seu desempenho. Além disso não existe uma solução geral e definitiva como o gradient cliping em casos de explosão do gradiente.
#
# Preparamos algumas redes para poder explorar um caso mais simples de vanishing gradient e também uma possivel solução. Começamos gerando um dataset simples de classificação e treinamos uma rede rasa que obtem uma boa performance.
# Ao aprofundarmos essa rede podemos notar que sua performance cai drasticamente se tornando quase tão eficiente quanto jogar uma moeda para chutar a classe do ponto, ela nem mesmo é capaz de overfittar os dados. Utilizaremos o TensorBoard para explorar os gradientes dessa rede mais profunda e tentar analisar essa queda de performance. Em seguida utilizaremos uma nova forma de inicialização dos pesos da rede para tentar recuperar nossa performance e novamente inspecionar os seus gradientes para tentar ganhar algum insight do que está acontecendo dentro dela.

# %% [markdown]
# ___________
#
# ## TensorBoard e Callbacks
#
# O TensorBoard é uma ferramenta de monitoramento e visualização de redes neurais. Nós o utilizaremos para visualizar os gradientes de nossa rede e poder entender mais afundo o que está causando nosso fraco desempenho. Para mais informações sobre o TensorBoard recomendamos este [guia da documentação oficial](https://www.tensorflow.org/tensorboard/get_started). O TensorBoard pode ser iniciado como parte do notebook usando a "magica"  `%load_ext tensorboard` para carrega-lo e `%tensorboard --logdir logs/` para inicia-lo. Outra maneira de utiliza-lo é independente pelo terminal a partir dos logs salvos na pasta `log_dir` com o comando `tensorboard --logdir="logs/"`.
#
# Para utilizar o TensorBoard nós utilizamos um callback ao treinar nossa rede.
#
# [Callbacks](https://keras.io/api/callbacks/#tensorboard) são objetos do Keras capazes de realizar ações em diferentes etapas do treinamento, como a cada final de epoch ou antes de cada mini-batch. Três exemplos interessates de callbacks são o [EarlyStopping](https://keras.io/api/callbacks/early_stopping/) que te permite encerrar o treinamento de sua rede quando você atinge uma performance minima desejada, o [ModelCheckpoint](https://keras.io/api/callbacks/model_checkpoint/) que lhe permite criar checkpoints do seu modelo para poder reiniciar o treinamento sem perder todo seu progresso em caso de algum problema (como seus gradientes explodindo por exemplo) e o [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler/) que lhe permite alterar o learning rate do seu otimizador conforme a epoch de treinamento.
#
# O TensorBoard possui um callback que nos permite monitorar o desempenho e parâmetros de nosso modelo ao longo do treinamento, porém para guardar os gradientes da rede necessitamos expandir e adaptar o [callback padrão do TensorBoard](https://keras.io/api/callbacks/tensorboard/).
#
# Nós ja implementamos para vocês uma extensão desse callback no arquivo `utils.py`.
# Para usar este callback basta importa-lo e declara-lo da seguinte maneira:
#
#
# ```python
# from utils import ExtendedTensorBoard
# log_dir = "logs/"
# tensorboard_callback = ExtendedTensorBoard(x=dados_treino, y=labels_treino,log_dir=log_dir,histogram_freq=1)
# ```
# ________________

# %% [markdown]
# ## Definindo nossos dados
# Primeiro definiremos um toy dataset bem simples que utilizaremos para nossos modelos e uma função auxiliar para facilitar a comparação de nossos modelos.
#
#
# Esses dados e redes foram inspirados e adaptados [deste post](https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/).

# %%
# gera dataset de classificação 
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)

# escala input para [-1,1]
scaler = MinMaxScaler(feature_range=(-1, 1))
X = scaler.fit_transform(X)

# plota visualização do dataset
for i in range(2):
    samples_ix = where(y == i)
    plt.scatter(X[samples_ix, 0], X[samples_ix, 1], label=str(i))
plt.legend()
plt.show()

# separa em teste e treino
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
def run_model(model,log_to_tb= False ,trainX=trainX,trainy=trainy,testX=testX,testy=testy):
    """
    Função auxiliar que recebe um modelo e realiza seu treinamento e avaliação no dataset.
    """
    model.summary()
    
    # compila modelo
    opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    #Cria log do modelo pra visualizarmos no TensorBoard se a flag estiver ligada
    callbacks = None
    if log_to_tb==True:
        log_dir = "logs/" + model.name
        callbacks=[ExtendedTensorBoard(x=trainX, y=trainy,log_dir=log_dir,histogram_freq=1)]
    

    # fit modelo
    history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=500, verbose=0, callbacks=callbacks)

    # avalia modelo
    _, train_acc = model.evaluate(trainX, trainy, verbose=0)
    _, test_acc = model.evaluate(testX, testy, verbose=0)
    print("\n")
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))


    # plota acurácia/training history
    plt.ylim(0, 1)
    plt.title("Acurácia "+ model.name)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Rede rasa
# Aqui temos uma rede rasa com apenas uma camada oculta e uma de output, note que ela é capaz de atingir uma performance razoavel após 300 epochs.
#
# Nos estamos utilizando um inicializador diferente do padrão para os pesos da camada, ele retirar os pesos iniciais a partir de uma distribuição uniforme no intervalo [0,1].

# %%
#define modelo raso
init = RandomUniform(minval=0, maxval=1)

model = keras.Sequential(name="modelo_raso")
model.add(keras.layers.Dense(5,
                       input_dim=2,
                       activation="tanh",
                       kernel_initializer=init,
                       name="raso_1"))
model.add(keras.layers.Dense(1,
                       activation='sigmoid',
                       kernel_initializer=init,
                       name="raso_output"))


run_model(model)
# Out:
# Model: "modelo_raso"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# raso_1 (Dense)               (None, 5)                 15
# _________________________________________________________________
# raso_output (Dense)          (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.814, Test: 0.794

# %% [markdown]
# ## Rede funda
#
# Agora tornaremos nossa rede mais funda com 5 camadas ocultas e uma de output, note como a performance cai drasticamente e se torna próxima a um chute aleatório. Embora o modelo seja mais complexo e poderoso nós não conseguimos treina-lo.

# %%
# define modelo mais fundo
init = RandomUniform(minval=0, maxval=1)

model = Sequential(name="modelo_fundo")
model.add(Dense(5, input_dim=2, activation='tanh', kernel_initializer=init,name="funda_1"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_2"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_3"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_4"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init,name="funda_output"))


run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_fundo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# funda_1 (Dense)              (None, 5)                 15
# _________________________________________________________________
# funda_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_4 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_5 (Dense)              (None, 5)                 30
# _________________________________________________________________
# funda_output (Dense)         (None, 1)                 6
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.626, Test: 0.600

# %% [markdown]
# ### Utilizando inicialização de Xavier Glorot
#
# Agora utilizaremos uma técnica de combate ao vanishing gradient, utilizaremos outro inicializador para os pesos da rede. O [inicializador de Xavier Glorot](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) é o inicializador default de algumas camadas do keras como a camada densa que utilizamos.

# %%
# define modelo mais fundo com inicializador de pesos melhor
model = Sequential(name="modelo_xavier")
model.add(Dense(5, input_dim=2, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_1"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_2"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_3"))
model.add(Dense(5, activation='tanh', kernel_initializer="glorot_uniform",name="xavier_4"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer="glorot_uniform", name="xavier_output"))

run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_xavier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xavier_1 (Dense)             (None, 5)                 15
# _________________________________________________________________
# xavier_2 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_3 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_4 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_5 (Dense)             (None, 5)                 30
# _________________________________________________________________
# xavier_output (Dense)        (None, 1)                 6
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.828, Test: 0.824

# %% [markdown]
# ## <font color='blue'>Questão 2 </font>
# Inicialize o TensorBoard e cheque os histogramas e as distribuições dos valores dos gradientes das 2 redes, como eles se diferem de uma rede para outra? Preste atenção em particular para a diferença de amplitude dos seus valores. Que conclusão podemos tirar? Insira/cole imagens do TensorBoard para basear seus argumentos, pode ser uma simples captura de tela.
#
# **Obs:** Você pode filtrar elementos ao escrever a tag "kernel_0_grads" como filtro para facilitar sua exploração dos gradientes dos pesos excluindo os termos de bias/viés.
#
# **Obs2:** Lembre-se de apagar a pasta `logs` se você for retreinar alguma das redes, caso contrário ele irá dar um append nos seus 2 treinamentos e seus graficos de loss e acurácia ficarão errados com loops ligando o começo de um treinamento ao final do outro.

# %%
#!rm -r logs

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-a1b7868dd1d56930" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a1b7868dd1d56930");
#           const url = new URL("/", window.location);
#           url.port = 6007;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Distribuições
#
#
# Inicialmente, é interessante ver a diferença na amplitude considerando a _rede funda_ (A) vs a _rede inicializada com Xavier Grolot_ (B). No caso da rede A, os valores nas épocas iniciais sempre ficam em torno de 0 até a época 200, aumentando para -0.15 a 0.15 nas épocas finais. Conforme as camadas mais profundas são avançadas, a amplitude dos gradientes é cada vez menor, chegando a ser de -0.1 a 0.1 no caso da segunda camada e -0.03 a 0.09 no caso da ultima camada. Em outras palavras, quanto mais funda a rede, o valor vai se aproximando de 0 e quanto mais épocas, mais oscilante os gradientes passam a ser.
#
# Em contrapartida, a rede B, inicializada com Xavier, por mais que os valores das camadas mais profundas tivessem um gradiente menor, a amplitude é mais "simétrica", sendo entre $\approx -0.06$ a $\approx 0.06$ na última camada, nas anteriores, esse valor manteve-se entre -0.4 a 0.4. Além disso, vale notar que no caso dessa rede B os valores dos gradientes parecem ter um comportamento mais "estacionário".
#
#
# As figuras abaixo representam os comportamenos analizados

# %% [markdown]
# ![](distrib_1.png) Distribuições da primeira camada

# %% [markdown]
# ![](distrib_2.png) Distribuições da segunda camada

# %% [markdown]
# ![](distrib_5.png) Distribuições da quinta camada

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Aqui, é nítido que apesar de que na primeira camada o comportamento das duas redes parece ser mais distribuido, a amplitude de valores da rede inicializada por Xavier (B) é maior que a rede inicializada de forma aleatória (A), sendo, respectivamente, -0.3 a 0.3 (rede B) e -0.08 a 0.1(A). Isso reflete-se com o decorrer das demais camadas, tornando-se bem perceptível na última, em que praticamente todas as distribuições de A tem um pico e concentração em torno de 0, enquanto a rede B apresenta uma distruição mais "espalhada" dos gradientes, mesmo que com um amaplitude de valores menor quando comparada à rede A.

# %% [markdown]
# ![](hist_1.png) Histogramas da primeira camada

# %% [markdown]
# ![](hist_2.png) Histogramas da segunda camada

# %% [markdown]
# ![](hist_5.png)Histogramas da quinta camada
